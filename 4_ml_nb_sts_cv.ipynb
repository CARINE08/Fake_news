# %%
# !pip3 install spacy -q
# !python3 -m spacy download en -q
# !python3 -m spacy download en_core_news_md -q
# Out:
# ⚠ As of spaCy v3.0, shortcuts like 'en' are deprecated. Please use the
# full pipeline package name 'en_core_web_sm' instead.
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
#
# ✘ No compatible package found for 'en_core_news_md' (spaCy v3.2.4)

# %%
import pandas as pd
import spacy
import matplotlib.pyplot as plt
from urllib.parse import urlparse
import pickle
from sklearn.feature_extraction.text import CountVectorizer

# %%
fn = "df_st_s.pk"
df = pd.read_pickle(fn)
df.sample(5)
# Out:
#       labels                                               text  \
# 4160       1  Californias Capitol building is second only to...
# 8441       1  GM has "repaid our government loan, in full, w...
# 6738       1  Weve seen in this last year tremendous things ...
# 9704       1  Obama did not open new lands to offshore drill...
# 6265       1  Says Rep. Maxine Waters, D-Calif., only needs ...
#
#                                               text_stem
# 4160  [california, capitol, build, is, second, onli,...
# 8441  [gm, has, "repaid, our, govern, loan,, in, ful...
# 6738  [weve, seen, in, this, last, year, tremend, th...
# 9704  [obama, did, not, open, new, land, to, offshor...
# 6265  [say, rep., maxin, waters,, d-calif.,, onli, n...

# %%
 df["text_stem"].map(lambda l: " ".join(l))
# Out:
# 0        say the anni list polit group support third-tr...
# 1        when did the declin of coal start? it start wh...
# 2        hillari clinton agre with john mccain "bi vote...
# 3        health care reform legisl is like to mandat fr...
# 4        the econom turnaround start at the end of my t...
#                                ...
# 10234    under the rule of the suprem court, ani lobbyi...
# 10235    there are a larger number of shark attack in f...
# 10236    democrat have now becom the parti of the [atla...
# 10237    say an altern to social secur that oper in gal...
# 10238    on lift the u.s. cuban embargo and allow trave...
# Name: text_stem, Length: 9399, dtype: object

# %%
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, f1_score, ConfusionMatrixDisplay, RocCurveDisplay
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.naive_bayes import MultinomialNB

Y = df["labels"]
X = df["text_stem"].map(lambda l: " ".join(l))

pipeline = Pipeline(
    [
        ("CV", CountVectorizer()), 
        ("mnb", MultinomialNB(class_prior=None))
    ]
)

param_grid = {
    
    
    "CV__ngram_range": [(1,1),(1,2)],
    "CV__max_df": [0.95,0.90,0.85,0.80,0.75,0.70,0.65,0.60,0.55,0.50, 0.45, 0.40],
    "CV__min_df": [0.0001, 0.00025, 0.0005, 0.001, 0.0025, 0.005],
    "CV__binary": [True,False],
    "mnb__alpha": [1, 4, 16, 64, 128, 256, 512],
    "mnb__fit_prior": [False]
    
    
}

SCORING = "f1"


grid = GridSearchCV(
    pipeline,
    n_jobs=-1,
    param_grid=param_grid,
    verbose=5,
    # réentrainer le meilleur modèle sur toutes les données
    refit=True,
    scoring=SCORING,
)





grid.fit(X, Y)
# Out:
# Fitting 5 folds for each of 2016 candidates, totalling 10080 fits
# [CV 3/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0001, CV__ngram_range=(1, 1), mnb__alpha=1, mnb__fit_prior=False;, score=0.668 total time=   1.5s
# [CV 1/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0001, CV__ngram_range=(1, 1), mnb__alpha=4, mnb__fit_prior=False;, score=0.745 total time=   1.6s
# [CV 4/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0001, CV__ngram_range=(1, 1), mnb__alpha=4, mnb__fit_prior=False;, score=0.746 total time=   1.6s
# [CV 2/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0001, CV__ngram_range=(1, 1), mnb__alpha=16, mnb__fit_prior=False;, score=0.759 total time=   1.4s
# [CV 4/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0001, CV__ngram_range=(1, 1), mnb__alpha=16, mnb__fit_prior=False;, score=0.760 total time=   1.0s
# [CV 2/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0001, CV__ngram_range=(1, 1), mnb__alpha=64, mnb__fit_prior=False;, score=0.760 total time=   1.0s
# [CV 4/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0001, CV__ngram_range=(1, 1), mnb__alpha=64, mnb__fit_prior=False;, score=0.760 total time=   1.3s
# [CV 2/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0001, CV__ngram_range=(1, 1), mnb__alpha=128, mnb__fit_prior=False;, score=0.760 total time=   1.4s
# [CV 5/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0001, CV__ngram_range=(1, 1), mnb__alpha=128, mnb__fit_prior=False;, score=0.760 total time=   1.0s
# [CV 3/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0001, CV__ngram_range=(1, 1), mnb__alpha=256, mnb__fit_prior=False;, score=0.760 total time=   1.5s
# [CV 1/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0001, CV__ngram_range=(1, 1), mnb__alpha=512, mnb__fit_prior=False;, score=0.760 total time=   1.4s
# [CV 3/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0001, CV__ngram_range=(1, 1), mnb__alpha=512, mnb__fit_prior=False;, score=0.760 total time=   1.5s
# [CV 1/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0001, CV__ngram_range=(1, 2), mnb__alpha=1, mnb__fit_prior=False;, score=0.727 total time=   3.8s
# [CV 4/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0001, CV__ngram_range=(1, 2), mnb__alpha=1, mnb__fit_prior=False;, score=0.731 total time=   3.3s
# [CV 2/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0001, CV__ngram_range=(1, 2), mnb__alpha=4, mnb__fit_prior=False;, score=0.760 total time=   3.5s
# [CV 3/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0001, CV__ngram_range=(1, 2), mnb__alpha=4, mnb__fit_prior=False;, score=0.764 total time=   4.2s
# [CV 1/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0001, CV__ngram_range=(1, 2), mnb__alpha=16, mnb__fit_prior=False;, score=0.760 total time=   4.4s
# [CV 4/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0001, CV__ngram_range=(1, 2), mnb__alpha=16, mnb__fit_prior=False;, score=0.760 total time=   4.0s
# [CV 2/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0001, CV__ngram_range=(1, 2), mnb__alpha=64, mnb__fit_prior=False;, score=0.760 total time=   4.6s
# [CV 5/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0001, CV__ngram_range=(1, 2), mnb__alpha=64, mnb__fit_prior=False;, score=0.760 total time=   4.0s
# [CV 3/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0001, CV__ngram_range=(1, 2), mnb__alpha=128, mnb__fit_prior=False;, score=0.760 total time=   4.6s
# [CV 1/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0001, CV__ngram_range=(1, 2), mnb__alpha=256, mnb__fit_prior=False;, score=0.760 total time=   3.6s
# [CV 4/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0001, CV__ngram_range=(1, 2), mnb__alpha=256, mnb__fit_prior=False;, score=0.760 total time=   4.6s
# [CV 2/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0001, CV__ngram_range=(1, 2), mnb__alpha=512, mnb__fit_prior=False;, score=0.760 total time=   3.9s
# [CV 5/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0001, CV__ngram_range=(1, 2), mnb__alpha=512, mnb__fit_prior=False;, score=0.760 total time=   4.9s
# [CV 4/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.00025, CV__ngram_range=(1, 1), mnb__alpha=1, mnb__fit_prior=False;, score=0.651 total time=   1.5s
# [CV 2/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.00025, CV__ngram_range=(1, 1), mnb__alpha=4, mnb__fit_prior=False;, score=0.698 total time=   1.4s
# [CV 5/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.00025, CV__ngram_range=(1, 1), mnb__alpha=4, mnb__fit_prior=False;, score=0.708 total time=   1.4s
# [CV 3/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.00025, CV__ngram_range=(1, 1), mnb__alpha=16, mnb__fit_prior=False;, score=0.757 total time=   1.2s
# [CV 1/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.00025, CV__ngram_range=(1, 1), mnb__alpha=64, mnb__fit_prior=False;, score=0.760 total time=   1.6s
# [CV 4/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.00025, CV__ngram_range=(1, 1), mnb__alpha=64, mnb__fit_prior=False;, score=0.760 total time=   1.4s
# [CV 2/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.00025, CV__ngram_range=(1, 1), mnb__alpha=128, mnb__fit_prior=False;, score=0.760 total time=   1.4s
# [CV 1/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.00025, CV__ngram_range=(1, 1), mnb__alpha=256, mnb__fit_prior=False;, score=0.760 total time=   1.5s
# [CV 4/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.00025, CV__ngram_range=(1, 1), mnb__alpha=256, mnb__fit_prior=False;, score=0.760 total time=   1.1s
# [CV 5/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.00025, CV__ngram_range=(1, 1), mnb__alpha=256, mnb__fit_prior=False;, score=0.760 total time=   1.3s
# [CV 3/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.00025, CV__ngram_range=(1, 1), mnb__alpha=512, mnb__fit_prior=False;, score=0.760 total time=   1.3s
# [CV 1/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.00025, CV__ngram_range=(1, 2), mnb__alpha=1, mnb__fit_prior=False;, score=0.677 total time=   3.6s
# [CV 4/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.00025, CV__ngram_range=(1, 2), mnb__alpha=1, mnb__fit_prior=False;, score=0.686 total time=   3.6s
# [CV 2/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.00025, CV__ngram_range=(1, 2), mnb__alpha=4, mnb__fit_prior=False;, score=0.740 total time=   3.5s
# [CV 2/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.00025, CV__ngram_range=(1, 2), mnb__alpha=16, mnb__fit_prior=False;, score=0.759 total time=   3.5s
# [CV 4/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.00025, CV__ngram_range=(1, 2), mnb__alpha=16, mnb__fit_prior=False;, score=0.761 total time=   3.8s
# [CV 3/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.00025, CV__ngram_range=(1, 2), mnb__alpha=64, mnb__fit_prior=False;, score=0.760 total time=   3.8s
# [CV 1/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.00025, CV__ngram_range=(1, 2), mnb__alpha=128, mnb__fit_prior=False;, score=0.760 total time=   4.2s
# [CV 4/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.00025, CV__ngram_range=(1, 2), mnb__alpha=128, mnb__fit_prior=False;, score=0.760 total time=   3.6s
# [CV 2/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.00025, CV__ngram_range=(1, 2), mnb__alpha=256, mnb__fit_prior=False;, score=0.760 total time=   3.2s
# [CV 1/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.00025, CV__ngram_range=(1, 2), mnb__alpha=512, mnb__fit_prior=False;, score=0.760 total time=   3.4s
# [CV 3/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.00025, CV__ngram_range=(1, 2), mnb__alpha=512, mnb__fit_prior=False;, score=0.760 total time=   3.5s
# [CV 1/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0005, CV__ngram_range=(1, 1), mnb__alpha=1, mnb__fit_prior=False;, score=0.645 total time=   1.3s
# [CV 4/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0005, CV__ngram_range=(1, 1), mnb__alpha=1, mnb__fit_prior=False;, score=0.654 total time=   1.5s
# [CV 2/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0005, CV__ngram_range=(1, 1), mnb__alpha=4, mnb__fit_prior=False;, score=0.671 total time=   1.4s
# [CV 5/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0005, CV__ngram_range=(1, 1), mnb__alpha=4, mnb__fit_prior=False;, score=0

# [CV 2/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0005, CV__ngram_range=(1, 1), mnb__alpha=64, mnb__fit_prior=False;, score=0.759 total time=   1.4s
# [CV 5/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0005, CV__ngram_range=(1, 1), mnb__alpha=64, mnb__fit_prior=False;, score=0.760 total time=   1.3s
# [CV 3/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0005, CV__ngram_range=(1, 1), mnb__alpha=128, mnb__fit_prior=False;, score=0.759 total time=   1.4s
# [CV 1/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0005, CV__ngram_range=(1, 1), mnb__alpha=256, mnb__fit_prior=False;, score=0.760 total time=   1.3s
# [CV 4/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0005, CV__ngram_range=(1, 1), mnb__alpha=256, mnb__fit_prior=False;, score=0.760 total time=   1.5s
# [CV 2/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0005, CV__ngram_range=(1, 1), mnb__alpha=512, mnb__fit_prior=False;, score=0.760 total time=   1.4s
# [CV 5/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0005, CV__ngram_range=(1, 1), mnb__alpha=512, mnb__fit_prior=False;, score=0.760 total time=   1.2s
# [CV 3/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0005, CV__ngram_range=(1, 2), mnb__alpha=1, mnb__fit_prior=False;, score=0.639 total time=   4.1s
# [CV 1/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0005, CV__ngram_range=(1, 2), mnb__alpha=4, mnb__fit_prior=False;, score=0.706 total time=   3.7s
# [CV 3/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0005, CV__ngram_range=(1, 2), mnb__alpha=4, mnb__fit_prior=False;, score=0.690 total time=   3.2s
# [CV 1/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0005, CV__ngram_range=(1, 2), mnb__alpha=16, mnb__fit_prior=False;, score=0.759 total time=   3.1s
# [CV 4/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0005, CV__ngram_range=(1, 2), mnb__alpha=16, mnb__fit_prior=False;, score=0.758 total time=   3.5s
# [CV 2/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0005, CV__ngram_range=(1, 2), mnb__alpha=64, mnb__fit_prior=False;, score=0.760 total time=   3.4s
# [CV 1/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0005, CV__ngram_range=(1, 2), mnb__alpha=128, mnb__fit_prior=False;, score=0.760 total time=   3.3s
# [CV 4/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0005, CV__ngram_range=(1, 2), mnb__alpha=128, mnb__fit_prior=False;, score=0.760 total time=   3.8s
# [CV 2/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0005, CV__ngram_range=(1, 2), mnb__alpha=256, mnb__fit_prior=False;, score=0.760 total time=   3.0s
# [CV 5/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0005, CV__ngram_range=(1, 2), mnb__alpha=256, mnb__fit_prior=False;, score=0.760 total time=   3.2s
# [CV 3/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0005, CV__ngram_range=(1, 2), mnb__alpha=512, mnb__fit_prior=False;, score=0.760 total time=   3.7s
# [CV 2/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.001, CV__ngram_range=(1, 1), mnb__alpha=1, mnb__fit_prior=False;, score=0.631 total time=   1.3s
# [CV 5/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.001, CV__ngram_range=(1, 1), mnb__alpha=1, mnb__fit_prior=False;, score=0.635 total time=   1.2s
# [CV 3/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.001, CV__ngram_range=(1, 1), mnb__alpha=4, mnb__fit_prior=False;, score=0.657 total time=   1.3s
# [CV 1/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.001, CV__ngram_range=(1, 1), mnb__alpha=16, mnb__fit_prior=False;, score=0.729 total time=   1.5s
# [CV 4/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.001, CV__ngram_range=(1, 1), mnb__alpha=16, mnb__fit_prior=False;, score=0.732 total time=   1.5s
# [CV 2/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.001, CV__ngram_range=(1, 1), mnb__alpha=64, mnb__fit_prior=False;, score=0.759 total time=   1.8s
# [CV 5/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.001, CV__ngram_range=(1, 1), mnb__alpha=64, mnb__fit_prior=False;, score=0.759 total time=   1.4s
# [CV 3/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.001, CV__ngram_range=(1, 1), mnb__alpha=128, mnb__fit_prior=False;, score=0.759 total time=   1.3s
# [CV 1/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.001, CV__ngram_range=(1, 1), mnb__alpha=256, mnb__fit_prior=False;, score=0.760 total time=   1.3s
# [CV 4/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.001, CV__ngram_range=(1, 1), mnb__alpha=256, mnb__fit_prior=False;, score=0.760 total time=   1.4s
# [CV 2/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.001, CV__ngram_range=(1, 1), mnb__alpha=512, mnb__fit_prior=False;, score=0.760 total time=   1.4s
# [CV 5/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.001, CV__ngram_range=(1, 1), mnb__alpha=512, mnb__fit_prior=False;, score=0.760 total time=   1.3s
# [CV 3/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=1, mnb__fit_prior=False;, score=0.636 total time=   3.3s
# [CV 1/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=4, mnb__fit_prior=False;, score=0.671 total time=   2.5s
# [CV 3/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=4, mnb__fit_prior=False;, score=0.656 total time=   3.1s
# [CV 1/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=16, mnb__fit_prior=False;, score=0.735 total time=   3.8s
# [CV 5/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=16, mnb__fit_prior=False;, score=0.735 total time=   3.5s
# [CV 3/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=64, mnb__fit_prior=False;, score=0.760 total time=   4.0s
# [CV 5/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=64, mnb__fit_prior=False;, score=0.759 total time=   3.8s
# [CV 3/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=128, mnb__fit_prior=False;, score=0.760 total time=   3.2s
# [CV 1/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=256, mnb__fit_prior=False;, score=0.760 total time=   3.1s
# [CV 4/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=256, mnb__fit_prior=False;, score=0.760 total time=   2.9s
# [CV 2/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=512, mnb__fit_prior=False;, score=0.760 total time=   3.1s
# [CV 5/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=512, mnb__fit_prior=False;, score=0.760 total time=   3.0s
# [CV 4/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0025, CV__ngram_range=(1, 1), mnb__alpha=1, mnb__fit_prior=False;, score=0.639 total time=   1.7s
# [CV 3/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0025, CV__ngram_range=(1, 1), mnb__alpha=4, mnb__fit_prior=False;, score=0.637 total time=   1.5s
# [CV 1/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0025, CV__ngram_range=(1, 1), mnb__alpha=16, mnb__fit_prior=False;, score=0.696 total time=   1.6s
# [CV 4/5] END CV__binary=True, CV__max_df=0.95, CV__min_df=0.0025, CV__ngram_range=(1, 1), mnb__alpha=16, mnb__fit_prior=False;, score=0.684 total time=   0.9s
# ...
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0005, CV__ngram_range=(1, 2), mnb__alpha=1, mnb__fit_prior=False;, score=0.641 total time=   3.6s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0005, CV__ngram_range=(1, 2), mnb__alpha=4, mnb__fit_prior=False;, score=0.703 total time=   3.1s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0005, CV__ngram_range=(1, 2), mnb__alpha=4, mnb__fit_prior=False;, score=0.684 total time=   2.9s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0005, CV__ngram_range=(1, 2), mnb__alpha=16, mnb__fit_prior=False;, score=0.759 total time=   3.3s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0005, CV__ngram_range=(1, 2), mnb__alpha=16, mnb__fit_prior=False;, score=0.760 total time=   3.4s
# [CV 2/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0005, CV__ngram_range=(1, 2), mnb__alpha=64, mnb__fit_prior=False;, score=0.760 total time=   3.1s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0005, CV__ngram_range=(1, 2), mnb__alpha=64, mnb__fit_prior=False;, score=0.760 total time=   1.9s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0005, CV__ngram_range=(1, 2), mnb__alpha=128, mnb__fit_prior=False;, score=0.760 total time=   3.6s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0005, CV__ngram_range=(1, 2), mnb__alpha=256, mnb__fit_prior=False;, score=0.760 total time=   3.2s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0005, CV__ngram_range=(1, 2), mnb__alpha=256, mnb__fit_prior=False;, score=0.760 total time=   3.2s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0005, CV__ngram_range=(1, 2), mnb__alpha=512, mnb__fit_prior=False;, score=0.760 total time=   3.3s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0005, CV__ngram_range=(1, 2), mnb__alpha=512, mnb__fit_prior=False;, score=0.760 total time=   3.8s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 1), mnb__alpha=1, mnb__fit_prior=False;, score=0.638 total time=   1.2s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 1), mnb__alpha=4, mnb__fit_prior=False;, score=0.650 total time=   1.3s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 1), mnb__alpha=16, mnb__fit_prior=False;, score=0.719 total time=   1.4s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 1), mnb__alpha=16, mnb__fit_prior=False;, score=0.717 total time=   1.7s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 1), mnb__alpha=64, mnb__fit_prior=False;, score=0.758 total time=   1.0s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 1), mnb__alpha=128, mnb__fit_prior=False;, score=0.760 total time=   1.0s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 1), mnb__alpha=128, mnb__fit_prior=False;, score=0.759 total time=   1.4s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 1), mnb__alpha=256, mnb__fit_prior=False;, score=0.760 total time=   1.1s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 1), mnb__alpha=256, mnb__fit_prior=False;, score=0.759 total time=   1.4s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 1), mnb__alpha=512, mnb__fit_prior=False;, score=0.759 total time=   1.4s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=1, mnb__fit_prior=False;, score=0.649 total time=   4.0s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=1, mnb__fit_prior=False;, score=0.644 total time=   3.2s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=4, mnb__fit_prior=False;, score=0.662 total time=   2.7s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=16, mnb__fit_prior=False;, score=0.730 total time=   2.6s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=16, mnb__fit_prior=False;, score=0.720 total time=   3.1s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=64, mnb__fit_prior=False;, score=0.756 total time=   3.2s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=64, mnb__fit_prior=False;, score=0.761 total time=   2.8s
# [CV 2/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=128, mnb__fit_prior=False;, score=0.760 total time=   2.6s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=128, mnb__fit_prior=False;, score=0.760 total time=   2.9s
# [CV 2/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=256, mnb__fit_prior=False;, score=0.760 total time=   3.2s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=256, mnb__fit_prior=False;, score=0.760 total time=   3.1s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=512, mnb__fit_prior=False;, score=0.759 total time=   3.8s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 1), mnb__alpha=1, mnb__fit_prior=False;, score=0.630 total time=   1.5s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 1), mnb__alpha=4, mnb__fit_prior=False;, score=0.662 total time=   1.4s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 1), mnb__alpha=4, mnb__fit_prior=False;, score=0.639 total time=   1.3s
# [CV 2/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 1), mnb__alpha=16, mnb__fit_prior=False;, score=0.668 total time=   1.2s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 1), mnb__alpha=64, mnb__fit_prior=False;, score=0.748 total time=   1.3s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 1), mnb__alpha=64, mnb__fit_prior=False;, score=0.751 total time=   1.1s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 1), mnb__alpha=128, mnb__fit_prior=False;, score=0.757 total time=   1.2s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 1), mnb__alpha=128, mnb__fit_prior=False;, score=0.759 total time=   1.5s
# [CV 2/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 1), mnb__alpha=256, mnb__fit_prior=False;, score=0.759 total time=   1.4s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 1), mnb__alpha=256, mnb__fit_prior=False;, score=0.757 total time=   1.3s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 1), mnb__alpha=512, mnb__fit_prior=False;, score=0.758 total time=   1.4s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 1), mnb__alpha=512, mnb__fit_prior=False;, score=0.760 total time=   1.6s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=1, mnb__fit_prior=False;, score=0.642 total time=   3.2s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=1, mnb__fit_prior=False;, score=0.651 total time=   3.2s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=4, mnb__fit_prior=False;, score=0.663 total time=   2.2s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=4, mnb__fit_prior=False;, score=0.667 total time=   3.7s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=16, mnb__fit_prior=False;, score=0.734 total time=   3.0s
# [CV 2/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=64, mnb__fit_prior=False;, score=0.760 total time=   3.2s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=64, mnb__fit_prior=False;, score=0.756 total time=   3.9s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=128, mnb__fit_prior=False;, score=0.759 total time=   4.0s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=256, mnb__fit_prior=False;, score=0.759 total time=   3.4s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=512, mnb__fit_prior=False;, score=0.760 total time=   3.0s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.001, CV__ngram_range=(1, 2), mnb__alpha=512, mnb__fit_prior=False;, score=0.760 total time=   2.7s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 1), mnb__alpha=1, mnb__fit_prior=False;, score=0.659 total time=   1.3s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 1), mnb__alpha=1, mnb__fit_prior=False;, score=0.634 total time=   1.5s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 1), mnb__alpha=4, mnb__fit_prior=False;, score=0.631 total time=   1.5s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 1), mnb__alpha=16, mnb__fit_prior=False;, score=0.694 total time=   1.4s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 1), mnb__alpha=16, mnb__fit_prior=False;, score=0.677 total time=   1.6s
# [CV 2/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 1), mnb__alpha=64, mnb__fit_prior=False;, score=0.737 total time=   0.9s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 1), mnb__alpha=64, mnb__fit_prior=False;, score=0.740 total time=   1.5s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 1), mnb__alpha=128, mnb__fit_prior=False;, score=0.755 total time=   1.2s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 1), mnb__alpha=256, mnb__fit_prior=False;, score=0.760 total time=   1.3s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 1), mnb__alpha=256, mnb__fit_prior=False;, score=0.758 total time=   1.3s
# [CV 2/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 1), mnb__alpha=512, mnb__fit_prior=False;, score=0.759 total time=   1.3s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 1), mnb__alpha=512, mnb__fit_prior=False;, score=0.758 total time=   1.5s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=1, mnb__fit_prior=False;, score=0.640 total time=   3.3s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=4, mnb__fit_prior=False;, score=0.660 total time=   3.0s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=4, mnb__fit_prior=False;, score=0.647 total time=   2.8s
# [CV 2/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=16, mnb__fit_prior=False;, score=0.680 total time=   3.5s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=16, mnb__fit_prior=False;, score=0.692 total time=   3.6s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=64, mnb__fit_prior=False;, score=0.756 total time=   3.0s
# [CV 2/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=128, mnb__fit_prior=False;, score=0.763 total time=   3.8s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=128, mnb__fit_prior=False;, score=0.749 total time=   3.7s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=256, mnb__fit_prior=False;, score=0.760 total time=   3.2s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=512, mnb__fit_prior=False;, score=0.761 total time=   2.7s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=512, mnb__fit_prior=False;, score=0.759 total time=   3.2s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=1, mnb__fit_prior=False;, score=0.656 total time=   1.1s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=1, mnb__fit_prior=False;, score=0.639 total time=   0.9s
# [CV 2/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=4, mnb__fit_prior=False;, score=0.625 total time=   1.2s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=4, mnb__fit_prior=False;, score=0.636 total time=   1.3s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=16, mnb__fit_prior=False;, score=0.675 total time=   1.4s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=16, mnb__fit_prior=False;, score=0.658 total time=   1.4s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=64, mnb__fit_prior=False;, score=0.707 total time=   1.3s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=128, mnb__fit_prior=False;, score=0.745 total time=   1.4s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=128, mnb__fit_prior=False;, score=0.755 total time=   1.3s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=256, mnb__fit_prior=False;, score=0.757 total time=   1.3s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=256, mnb__fit_prior=False;, score=0.764 total time=   1.2s
# [CV 2/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=512, mnb__fit_prior=False;, score=0.756 total time=   1.2s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=512, mnb__fit_prior=False;, score=0.753 total time=   1.6s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=1, mnb__fit_prior=False;, score=0.631 total time=   3.2s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=4, mnb__fit_prior=False;, score=0.658 total time=   2.7s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=4, mnb__fit_prior=False;, score=0.631 total time=   2.4s
# GridSearchCV(estimator=Pipeline(steps=[('CV', CountVectorizer()),
#                                        ('mnb', MultinomialNB())]),
#              n_jobs=-1,
#              param_grid={'CV__binary': [True, False],
#                          'CV__max_df': [0.95, 0.9, 0.85, 0.8, 0.75, 0.7, 0.65,
#                                         0.6, 0.55, 0.5, 0.45, 0.4],
#                          'CV__min_df': [0.0001, 0.00025, 0.0005, 0.001, 0.0025,
#                                         0.005],
#                          'CV__ngram_range': [(1, 1), (1, 2)],
#                          'mnb__alpha': [1, 4, 16, 64, 128, 256, 512],
#                          'mnb__fit_prior': [False]},
#              scoring='f1', verbose=5)

# %%
grid.best_estimator_
# Out:
# Pipeline(steps=[('CV',
#                  CountVectorizer(binary=True, max_df=0.95, min_df=0.00025,
#                                  ngram_range=(1, 2))),
#                 ('mnb', MultinomialNB(alpha=16, fit_prior=False))])

# %%
import joblib
joblib.dump(grid, '4_ml_nb_sts_cv_best.pkl')
# Out:
# ['4_ml_nb_sts_cv_best.pkl']
# [CV 2/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=1, mnb__fit_prior=False;, score=0.641 total time=   2.3s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=1, mnb__fit_prior=False;, score=0.642 total time=   3.1s
# [CV 2/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=4, mnb__fit_prior=False;, score=0.641 total time=   3.1s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=4, mnb__fit_prior=False;, score=0.651 total time=   3.0s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=16, mnb__fit_prior=False;, score=0.682 total time=   2.8s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=64, mnb__fit_prior=False;, score=0.744 total time=   2.0s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=64, mnb__fit_prior=False;, score=0.746 total time=   3.2s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=128, mnb__fit_prior=False;, score=0.758 total time=   2.9s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=128, mnb__fit_prior=False;, score=0.758 total time=   2.7s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=256, mnb__fit_prior=False;, score=0.759 total time=   2.5s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=256, mnb__fit_prior=False;, score=0.760 total time=   3.3s
# [CV 2/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=512, mnb__fit_prior=False;, score=0.760 total time=   3.2s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=512, mnb__fit_prior=False;, score=0.759 total time=   3.0s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=1, mnb__fit_prior=False;, score=0.626 total time=   1.3s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=4, mnb__fit_prior=False;, score=0.660 total time=   1.3s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=4, mnb__fit_prior=False;, score=0.627 total time=   1.3s
# [CV 2/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=16, mnb__fit_prior=False;, score=0.641 total time=   1.5s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=64, mnb__fit_prior=False;, score=0.727 total time=   1.4s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=64, mnb__fit_prior=False;, score=0.723 total time=   1.8s
# [CV 2/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=128, mnb__fit_prior=False;, score=0.731 total time=   0.9s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=128, mnb__fit_prior=False;, score=0.744 total time=   1.3s
# [CV 2/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=256, mnb__fit_prior=False;, score=0.757 total time=   1.3s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=256, mnb__fit_prior=False;, score=0.748 total time=   1.4s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=512, mnb__fit_prior=False;, score=0.759 total time=   1.4s
# [CV 2/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=1, mnb__fit_prior=False;, score=0.624 total time=   1.7s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=1, mnb__fit_prior=False;, score=0.651 total time=   3.4s
# [CV 2/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=4, mnb__fit_prior=False;, score=0.627 total time=   3.3s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=4, mnb__fit_prior=False;, score=0.640 total time=   2.9s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=16, mnb__fit_prior=False;, score=0.651 total time=   3.1s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=64, mnb__fit_prior=False;, score=0.721 total time=   1.5s
# [CV 2/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=64, mnb__fit_prior=False;, score=0.702 total time=   3.0s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=64, mnb__fit_prior=False;, score=0.723 total time=   2.9s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=128, mnb__fit_prior=False;, score=0.749 total time=   2.9s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=256, mnb__fit_prior=False;, score=0.755 total time=   3.2s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=256, mnb__fit_prior=False;, score=0.762 total time=   3.7s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=512, mnb__fit_prior=False;, score=0.757 total time=   3.1s
# [CV 2/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 1), mnb__alpha=128, mnb__fit_prior=False;, score=0.759 total time=   1.4s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 1), mnb__alpha=128, mnb__fit_prior=False;, score=0.748 total time=   1.4s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 1), mnb__alpha=256, mnb__fit_prior=False;, score=0.759 total time=   1.3s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 1), mnb__alpha=512, mnb__fit_prior=False;, score=0.761 total time=   1.4s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 1), mnb__alpha=512, mnb__fit_prior=False;, score=0.758 total time=   1.2s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=1, mnb__fit_prior=False;, score=0.653 total time=   2.7s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=1, mnb__fit_prior=False;, score=0.644 total time=   3.3s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=4, mnb__fit_prior=False;, score=0.635 total time=   3.0s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=16, mnb__fit_prior=False;, score=0.696 total time=   3.5s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=16, mnb__fit_prior=False;, score=0.680 total time=   3.9s
# [CV 2/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=64, mnb__fit_prior=False;, score=0.741 total time=   3.2s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=64, mnb__fit_prior=False;, score=0.743 total time=   3.6s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=128, mnb__fit_prior=False;, score=0.761 total time=   2.6s
# [CV 2/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=256, mnb__fit_prior=False;, score=0.760 total time=   3.5s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=256, mnb__fit_prior=False;, score=0.756 total time=   3.4s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.0025, CV__ngram_range=(1, 2), mnb__alpha=512, mnb__fit_prior=False;, score=0.759 total time=   3.9s
# [CV 2/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=1, mnb__fit_prior=False;, score=0.626 total time=   1.7s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=1, mnb__fit_prior=False;, score=0.636 total time=   1.4s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=4, mnb__fit_prior=False;, score=0.633 total time=   1.2s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=16, mnb__fit_prior=False;, score=0.647 total time=   1.4s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=16, mnb__fit_prior=False;, score=0.651 total time=   1.3s
# [CV 2/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=64, mnb__fit_prior=False;, score=0.698 total time=   1.2s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=64, mnb__fit_prior=False;, score=0.722 total time=   1.3s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=128, mnb__fit_prior=False;, score=0.730 total time=   1.6s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=256, mnb__fit_prior=False;, score=0.749 total time=   1.3s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=512, mnb__fit_prior=False;, score=0.759 total time=   1.2s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 1), mnb__alpha=512, mnb__fit_prior=False;, score=0.758 total time=   1.3s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=1, mnb__fit_prior=False;, score=0.655 total time=   3.7s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=1, mnb__fit_prior=False;, score=0.637 total time=   3.6s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=4, mnb__fit_prior=False;, score=0.651 total time=   3.3s
# [CV 2/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=16, mnb__fit_prior=False;, score=0.647 total time=   3.1s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=16, mnb__fit_prior=False;, score=0.657 total time=   2.7s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=64, mnb__fit_prior=False;, score=0.707 total time=   3.0s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=128, mnb__fit_prior=False;, score=0.738 total time=   2.3s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=128, mnb__fit_prior=False;, score=0.737 total time=   3.4s
# [CV 2/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=256, mnb__fit_prior=False;, score=0.762 total time=   3.3s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=512, mnb__fit_prior=False;, score=0.758 total time=   3.6s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=512, mnb__fit_prior=False;, score=0.760 total time=   3.0s
# [CV 1/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=16, mnb__fit_prior=False;, score=0.673 total time=   2.8s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=16, mnb__fit_prior=False;, score=0.656 total time=   4.4s
# [CV 4/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=64, mnb__fit_prior=False;, score=0.720 total time=   3.0s
# [CV 2/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=128, mnb__fit_prior=False;, score=0.738 total time=   2.5s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=128, mnb__fit_prior=False;, score=0.747 total time=   3.2s
# [CV 3/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=256, mnb__fit_prior=False;, score=0.752 total time=   3.0s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=256, mnb__fit_prior=False;, score=0.750 total time=   3.2s
# [CV 2/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=512, mnb__fit_prior=False;, score=0.759 total time=   2.6s
# [CV 5/5] END CV__binary=False, CV__max_df=0.4, CV__min_df=0.005, CV__ngram_range=(1, 2), mnb__alpha=512, mnb__fit_prior=False;, score=0.754 total time=   3.0s

# %%
grid.best_score_
# Out:
# 0.7602555667170761

# %%
len(grid.best_estimator_['CV'].vocabulary_)
# Out:
# 15001
